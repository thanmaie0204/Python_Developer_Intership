# %%
name = "Python Developer"
age = 20
height = 5.4
is_student = True

print(name)
print(age)
print(height)
print(is_student)
# Out:
# Python Developer
# 20
# 5.4
# True

# %%
a = 20
b = 5

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b)
# Out:
# 25
# 15
# 100
# 4.0
# 0

# %%
marks = 75

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
fruits = ["Apple", "Banana", "Mango"]

for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Banana
# Mango

# %%
def greet(name):
    return "Hello " + name

print(greet("Python Developer"))
# Out:
# Hello Python Developer

# %%
student = {
    "name": "Thanu",
    "age": 20,
    "course": "BTech CSE"
}

print(student)
# Out:
# {'name': 'Thanu', 'age': 20, 'course': 'BTech CSE'}

# %%
try:
    a = 10
    b = 0
    print(a / b)
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %%
name = input("Enter student name: ")
marks = float(input("Enter marks: "))

if marks >= 90:
    grade = "A"
elif marks >= 75:
    grade = "B"
elif marks >= 60:
    grade = "C"
elif marks >= 40:
    grade = "D"
else:
    grade = "F"

print("Student:", name)
print("Grade:", grade) sss
# Out:
# Enter student name:  thanu
# Enter marks:  75
# Student: thanu
# Grade: B
